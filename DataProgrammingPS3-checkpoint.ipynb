# %% [markdown]
# # Problem Set-3 Data Programming

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Question 1

# %%
users = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|', index_col='user_id')
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
# what is the mean age per occupation?
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
# Discover the Male ratio per occupation and sort it from the most to the least

users['is_male'] = users.gender.apply(lambda x: True if x == 'M' else False)
(users.groupby('occupation').is_male.sum() / users.groupby('occupation').gender.count()).sort_values(ascending = False)
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# dtype: float64

# %%
# For each occupation, calculate the minimum and maximum ages
occupation_min = users.groupby('occupation').age.min()
occupation_max = users.groupby('occupation').age.max()
age_by_occupation = users.groupby('occupation').age.agg(['min', 'max'])
age_by_occupation
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
# For each combination of occupation and sex, calculate the mean age

mean_age_by_gender = users.groupby(['occupation', 'gender']).age.mean()
mean_age_by_gender
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
# For each occupation present the percentage of women and men

gender_ocup = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})
occup_count = users.groupby(['occupation']).count()
occup_gender = gender_ocup.div(occup_count, level = "occupation")
percentage_by_occ_and_gender = occup_gender.loc[:, 'gender']
percentage_by_occ_and_gender
# Out:
# occupation     gender
# administrator  F         0.455696
#                M         0.544304
# artist         F         0.464286
#                M         0.535714
# doctor         M         1.000000
# educator       F         0.273684
#                M         0.726316
# engineer       F         0.029851
#                M         0.970149
# entertainment  F         0.111111
#                M         0.888889
# executive      F         0.093750
#                M         0.906250
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         F         0.166667
#                M         0.833333
# librarian      F         0.568627
#                M         0.431373
# marketing      F         0.384615
#                M         0.615385
# none           F         0.444444
#                M         0.555556
# other          F         0.342857
#                M         0.657143
# ...

# %% [markdown]
# # Question 2

# %%
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv', sep=',')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
# How many team participated in the Euro2012? --> 16 teams

no_of_teams = euro12.shape[0]
no_of_teams
# Out:
# 16

# %%
# What is the number of columns in the dataset?  ---> 34 columns

euro12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
# View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Sort the teams by Red Cards, then to Yellow Cards

red_yellow = discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending = False)
red_yellow
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
# Calculate the mean Yellow Cards given per Team

mean_yellow_by_team = round(discipline['Yellow Cards'].mean())
mean_yellow_by_team
# Out:
# 7

# %%
# Filter teams that scored more than 6 goals

teams_more_6 = euro12[euro12.Goals > 6]
teams_more_6
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
# Step 11. Select the teams that start with G

teams_G = euro12[euro12.Team.str.startswith('G')]
teams_G
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
# Select the first 7 columns

first_7 = euro12.iloc[: , 0:7]
first_7
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Select all columns except the last 3

all_col_except_last3 = euro12.iloc[: , :-3]
all_col_except_last3
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Present only the Shooting Accuracy from England, Italy and Russia

eng_italy_russia = euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team','Shooting Accuracy']]
eng_italy_russia
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# ## Question 3

# %%
# Create 3 differents Series, each of length 100, as follows:
#• The first a random number from 1 to 4
#• The second a random number from 1 to 3
#• The third a random number from 10,000 to 30,000

s1 = pd.Series(np.random.randint(1, high=5, size=100, dtype='l'))
s2 = pd.Series(np.random.randint(1, high=4, size=100, dtype='l'))
s3 = pd.Series(np.random.randint(10000, high=30001, size=100, dtype='l'))

print(s1, s2, s3)
# Out:
# 0     2
# 1     1
# 2     4
# 3     2
# 4     1
#      ..
# 95    4
# 96    4
# 97    2
# 98    2
# 99    1
# Length: 100, dtype: int32 0     2
# 1     3
# 2     2
# 3     3
# 4     2
#      ..
# 95    2
# 96    1
# 97    1
# 98    2
# 99    1
# Length: 100, dtype: int32 0     11681
# 1     17926
# 2     16136
# 3     11661
# 4     29065
#       ...
# 95    19936
# 96    29825
# 97    11915
# 98    10176
# 99    27436
# Length: 100, dtype: int32

# %%
# Create a DataFrame by joinning the Series by column

housemkt = pd.concat([s1, s2, s3], axis=1)
housemkt.head()
# Out:
#    0  1      2
# 0  2  2  11681
# 1  1  3  17926
# 2  4  2  16136
# 3  2  3  11661
# 4  1  2  29065

# %%
#  Change the name of the columns to bedrs, bathrs, price_sqr_meter

housemkt.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)
housemkt.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      2       2            11681
# 1      1       3            17926
# 2      4       2            16136
# 3      2       3            11661
# 4      1       2            29065

# %%
# Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

bigcolumn = pd.concat([s1, s2, s3], axis=0)
bigcolumn = bigcolumn.to_frame()
bigcolumn
# Out:
#         0
# 0       2
# 1       1
# 2       4
# 3       2
# 4       1
# ..    ...
# 95  19936
# 96  29825
# 97  11915
# 98  10176
# 99  27436
#
# [300 rows x 1 columns]

# %%
# Ops it seems it is going only until index 99. Is it true? --> no the index are kept but the length of the DataFrame is 300

len(bigcolumn)
# Out:
# 300

# %%
# Reindex the DataFrame so it goes from 0 to 299

bigcolumn.reset_index(drop=True, inplace=True)
bigcolumn
# Out:
#          0
# 0        2
# 1        1
# 2        4
# 3        2
# 4        1
# ..     ...
# 295  19936
# 296  29825
# 297  11915
# 298  10176
# 299  27436
#
# [300 rows x 1 columns]

# %% [markdown]
# ## Question 4

# %%
import datetime as dt

# %%
data = pd.read_csv("C:/Users/ashut/Desktop/GEORGIAN FILES/SEM1/05. Data Programming-BDAT1004 (Ethan)/problem set 3/wind.data")
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
# Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

data["Date"] = pd.to_datetime(data[["Yr","Mo","Dy"]].astype(str).agg('-'.join, axis=1))
data = data.drop(columns=["Yr","Mo","Dy"])
data.head()
# Out:
#      RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL    CLO    BEL  \
# 0  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83  12.58  18.50
# 1  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79   9.67  17.54
# 2  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50   7.67  12.75
# 3  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83   5.88   5.46
# 4  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92  10.34  12.92
#
#      MAL       Date
# 0  15.04 2061-01-01
# 1  13.83 2061-01-02
# 2  12.71 2061-01-03
# 3  10.88 2061-01-04
# 4  11.83 2061-01-05

# %%
# Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

data["Date"] = np.where(pd.DatetimeIndex(data["Date"]).year < 2000,data.Date,data.Date - pd.offsets.DateOffset(years=100))
data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL       Date
# 0     18.50  15.04 1961-01-01
# ...

# %%
# Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

newData = data.set_index("Date")
newData.index.astype("datetime64[ns]")
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Date', length=6574, freq=None)

# %%
# Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.

print(newData.isnull().values.ravel().sum())
# Out:
# 31

# %%
# Compute how many non-missing values there are in total.

x=newData.count()
print("Total Non-missing values:",x.sum())
# Out:
# Total Non-missing values: 78857

# %%
# Calculate the mean windspeeds of the windspeeds over all the locations and all the times. A single number for the entire dataset.

y = newData.mean()
y.mean()
# Out:
# 10.227982360836924

# %%
# Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days A different set of numbers for each location.

def stats(x):
    x = pd.Series(x)
    Min = x.min()
    Max = x.max()
    Mean = x.mean()
    Std = x.std()
    res = [Min,Max,Mean,Std]
    indx = ["Min","Max","Mean","Std"]
    res = pd.Series(res,index=indx)
    return res
loc_stats = newData.apply(stats)
loc_stats
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# Min    0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# Max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# Mean  12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# Std    5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# Min    0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# Max   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# Mean   9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# Std    4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %%
# Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
# A different set of numbers for each day.

day_stats = newData.apply(stats,axis=1)
day_stats.head()
# Out:
#              Min    Max       Mean       Std
# Date
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356

# %%
# Find the average windspeed in January for each location Treat January 1961 and January 1962 both as January.

january_data = newData[newData.index.month == 1]
print ("January windspeeds:")
print (january_data.mean())
# Out:
# January windspeeds:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
# Downsample the record to a yearly frequency for each location.
print( "Yearly:\n", newData.resample('A').mean())
# Out:
# Yearly:
#                    RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %%
# Downsample the record to a monthly frequency for each location
print ("Monthly:", newData.resample('M').mean())
# Out:
# Monthly:                   RPT        VAL        ROS       KIL        SHA        BIR  \
# Date
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
# Downsample the record to a weekly frequency for each location.

print ("Weekly:", newData.resample('W').mean())
# Out:
# Weekly:                   RPT        VAL        ROS        KIL        SHA        BIR  \
# Date
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %%
# Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

newdata = newData.groupby(lambda d: (d.month, d.year))
print ("Mean wind speed for each month in each location")
print (newdata.mean())
# Out:
# Mean wind speed for each month in each location
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# (1, 1961)   14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# (1, 1962)   14.783871  13.160323  12.591935  7.538065  11.779677   8.720000
# (1, 1963)   14.868387  11.112903  15.121613  6.635806  11.080645   7.835484
# (1, 1964)   12.661290  11.818387  11.741290  6.953548  11.400645   6.865806
# (1, 1965)   15.741613  15.546774  15.274194  8.258387  13.588065   9.251290
# ...               ...        ...        ...       ...        ...        ...
# (12, 1974)  18.511290  17.805806  14.773871  9.734839  16.944194  10.153871
# (12, 1975)  11.655484   8.686774  11.217742  4.478387   6.628710   4.178065
# (12, 1976)  11.962258  10.086774  10.474516  3.383871   7.645484   6.148387
# (12, 1977)  14.751935  12.744839  13.469677  6.592258  11.247742   9.466774
# (12, 1978)  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# ## Question 5

# %%
# Assign it to a variable called chipo
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'    
chipo = pd.read_csv(url, sep = '\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# See the first 10 entries
first_10 = chipo.head(10)
first_10
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# What is the number of observations in the dataset?

chipo.shape[0]
# Out:
# 4622

# %%
# What is the number of columns in the dataset?
chipo.shape[1]
# Out:
# 5

# %%
# Print the name of all the columns.
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# How is the dataset indexed?

chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# Which was the most-ordered item?
chipo.item_name.value_counts().head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %%
# For the most-ordered item, how many items were ordered?

chipo.item_name.unique().shape[0]
# Out:
# 50

# %%
# What was the most ordered item in the choice_description column?
chipo.choice_description.value_counts().head()
# Out:
# [Diet Coke]                                                                          134
# [Coke]                                                                               123
# [Sprite]                                                                              77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]     40
# Name: choice_description, dtype: int64

# %%
# How many items were orderd in total?

chipo.quantity.sum()
# Out:
# 4972

# %%
# Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type

def num_float(x):
    return float(x[1:-1])
chipo.item_price = chipo.item_price.apply(num_float)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
# How much was the revenue for the period in the dataset?
chipo.item_price.sum()
# Out:
# 34500.16

# %%
# How many orders were made in the period?
chipo.order_id.value_counts().count()
# Out:
# 1834

# %%
# What is the average revenue amount per order?
total_order = chipo.order_id.nunique()
chipo['revenue'] = chipo['quantity']*chipo.item_price
total_revenue = chipo.revenue.sum()
total_revenue / total_order
# Out:
# 21.39423118865867

# %%
# How many different items are sold?
chipo.item_name.nunique()
# Out:
# 50

# %% [markdown]
# ## Question 6

# %%
import matplotlib.pyplot as plt

us_marriage_divorce_data = pd.read_csv('C:/Users/ashut/Desktop/GEORGIAN FILES/SEM1/05. Data Programming-BDAT1004 (Ethan)/problem set 3/us-marriages-divorces-1867-2014.csv')
years = us_marriage_divorce_data['Year'].values
marriages_per_capita = us_marriage_divorce_data['Marriages_per_1000'].values
divorces_per_capita = us_marriage_divorce_data['Divorces_per_1000'].values

# %%
plt.title('number of marriages in the U.S. between 1867 and 2014')
plt.plot(years, marriages_per_capita, label = "marriages")
plt.plot(years, divorces_per_capita, label = "divorces per capita")
plt.legend()
plt.show()

# %% [markdown]
# ## Question 7

# %%
import pandas as pd

us_marriage_divorce_data = us_marriage_divorce_data[us_marriage_divorce_data['Year'].apply(lambda x: x in [1900, 1950, 2000])]
years = us_marriage_divorce_data['Year'].values
marriages_per_capita1 = us_marriage_divorce_data['Marriages_per_1000'].values
divorces_per_capita1 = us_marriage_divorce_data['Divorces_per_1000'].values

# %%
plt.title('number of marriages in the U.S. between 1900, 1950, and 2000')
plt.plot(years, marriages_per_capita1, label = "marriages")
plt.plot(years, divorces_per_capita1, label = "divorces per capita")
plt.legend()
plt.show()

# %% [markdown]
# ## Question 8

# %%
import pandas as pd

hollywood_actor_kills = pd.read_csv('C:/Users/ashut/Desktop/GEORGIAN FILES/SEM1/05. Data Programming-BDAT1004 (Ethan)/problem set 3/actor_kill_counts.csv')
actor_names = hollywood_actor_kills['Actor'].values
kill_counts = hollywood_actor_kills['Count'].values

# %%
plt.barh(actor_names, kill_counts)
plt.xlabel("kill counts")
plt.ylabel("actor names")  
plt.title("deadliest actors in Hollywood")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Question 9

# %%
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated

import pandas as pd

roman_emperors = pd.read_csv('C:/Users/ashut/Desktop/GEORGIAN FILES/SEM1/05. Data Programming-BDAT1004 (Ethan)/problem set 3/roman-emperor-reigns.csv')
assassinated_emperors = roman_emperors[roman_emperors['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]
number_assassinated = len(assassinated_emperors)
other_deaths = len(roman_emperors) - number_assassinated
label = ['assassinated', 'other']
piedata = [number_assassinated, other_deaths]
fig = plt.figure(figsize =(10, 7))
plt.pie(piedata, labels = label)

# show plot
plt.show()

# %% [markdown]
# ## Question 10

# %%
arcade_revenue_cs_doctorates = pd.read_csv('C:/Users/ashut/Desktop/GEORGIAN FILES/SEM1/05. Data Programming-BDAT1004 (Ethan)/problem set 3/arcade-revenue-vs-cs-doctorates.csv')
years = arcade_revenue_cs_doctorates['Year']
arcade_revenue = arcade_revenue_cs_doctorates['Total Arcade Revenue (billions)'].values
cs_doctorates_awarded = arcade_revenue_cs_doctorates['Computer Science Doctorates Awarded (US)'].values

# %%
plt.scatter(years, cs_doctorates_awarded, label = "cs_doctorates_awarded")
plt.scatter(years, arcade_revenue, label = "arcade_revenue")
plt.xlabel("year")
plt.ylabel("revenue")  
plt.title(" total revenue earned by arcades and the number of Computer Science PhDs awarded")
plt.show()
